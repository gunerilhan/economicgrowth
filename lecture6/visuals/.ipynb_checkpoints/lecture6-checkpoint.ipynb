# %% [markdown]
# ### Figures and Tables of Lectue 6
#
# This notebook is in html. To be able to run it, please click: [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gunerilhan/economicgrowth/blob/master/lecture6/visuals/lecture6.ipynb)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline
import seaborn as sns
style.use('https://gunerilhan.github.io/img/fivethirtyeight-modified.mplstyle')
from tabulate import tabulate
from itertools import product

# %%
colors = {0:['#264653','#219D8F','#E9C46A','#F4A261','#E76F51'],
  1:['#003049','#D62828','#F77F00','#FCBF49','#EAE2B7'],
  2:['#F72585','#7209B7','#3A0CA3','#4361EE','#4CC9F0'],
  3: ['#165aa7','#cb495c','#bb60d5','#f47915','#06ab54','#002070','#b27d12','#007030']}

# %%
# Penn World Tables, version 10.0
# Accessed from https://www.rug.nl/ggdc/productivity/pwt/?lang=en
# Read in legend
pwt_legend = pd.read_excel('https://www.rug.nl/ggdc/docs/pwt100.xlsx',sheet_name='Legend')
# Drop entries with missing data
pwt_legend.dropna(subset=['Variable name','Variable definition'],inplace=True)
# Create a dictionary of variable descriptions
pwt_legend = dict(zip(pwt_legend['Variable name'],pwt_legend['Variable definition']))

# %%
# Read in the data
pwt = pd.read_excel('https://www.rug.nl/ggdc/docs/pwt100.xlsx',sheet_name='Data')

# %%
country_codes = dict((zip(pwt[['countrycode','country']].drop_duplicates().countrycode.values,
 pwt[['countrycode','country']].drop_duplicates().country.values,)))

# %%
# pwt_legend = pd.read_excel('https://www.rug.nl/ggdc/docs/pwt91.xlsx',sheet_name='Legend')
# pwt_legend.dropna(inplace=True)
# pwt_legend = dict(zip(pwt_legend['Variable name'],pwt_legend['Variable definition']))
# pwt = pd.read_excel('https://www.rug.nl/ggdc/docs/pwt91.xlsx',sheet_name='Data')

# %%
prod = pd.read_csv('gdp_per_hour_OECD.csv')

# %%
prod_UK = prod[prod.LOCATION == 'GBR']

# %%
p = np.poly1d(np.polyfit(prod_UK.loc[:1288].TIME,prod_UK.loc[:1288].Value,1))

# %%
fig,ax = plt.subplots(figsize=(8,6))
ax.plot(prod_UK.TIME,prod_UK.Value,color=colors[1][1])
ax.plot(prod_UK.TIME,p(prod_UK.TIME),color=colors[1][0])
ax.annotate('Labor productivity',(2010,93),color=colors[1][1],fontsize=16)
ax.annotate('Trend',(2010,110),color=colors[1][0],fontsize=16)
ax.set_xlabel('Year')
ax.set_ylabel('GDP per hours worked, 2015=100')
ax.set_xlim(xmax=2023)
ax.set_ylim(ymax=123,ymin=35)
ax.text(1962,20,'Source: OECD',fontsize=16);
plt.savefig('../files/uk_productivity-trend.svg',bbox_inches='tight')

# %%
year_ = 2019
(p(year_)/prod_UK[prod_UK.TIME == year_].Value-1).round(decimals=2)
# Out:
# 1299    0.14
# Name: Value, dtype: float64

# %%
countries_pick = ['USA','GBR','DEU','FRA','JPN','NZL']

# %%
year_0 = 1970
year_mid = 2008
year_last = 2019
period_init = [year_0,year_mid]
period_last = [year_mid+1,year_last]

# %%
def growth(group,begin=year_0,mid=year_mid,end=year_last):
    try:
        g_1 = (group[group.TIME==mid].Value.values[0]/
               group[group.TIME==begin].Value.values[0])**(1/(mid-begin))-1
        g_2 = (group[group.TIME==end].Value.values[0]/
               group[group.TIME==mid+1].Value.values[0])**(1/(end-mid-1))-1
    except Exception:
        g_1 = np.nan
        g_2 = np.nan
    return pd.Series({f'Growth rate, {begin}-{mid}':g_1,
                     f'Growth rate, {mid+1}-{end}':g_2})

# %%
growth_rates = prod.groupby('LOCATION').apply(growth).reset_index()

# %%
growth_rates['Country']=growth_rates.LOCATION.map(country_codes)

# %%
growth_rates.set_index('LOCATION',inplace=True)

# %%
growth_rates.loc[countries_pick]
# Out:
#           Growth rate, 1970-2008  Growth rate, 2009-2019         Country
# LOCATION
# USA                     0.016984                0.008544   United States
# GBR                     0.024165                0.004598  United Kingdom
# DEU                     0.024015                0.010566         Germany
# FRA                     0.025548                0.009075          France
# JPN                     0.030160                0.011568           Japan
# NZL                     0.012121                0.005362     New Zealand

# %%
print(tabulate((growth_rates.loc[countries_pick].set_index('Country')*100).round(decimals=1),
               tablefmt="pipe", 
               showindex=True,headers="keys"))
# Out:
# | Country        |   Growth rate, 1970-2008 |   Growth rate, 2009-2019 |
# |:---------------|-------------------------:|-------------------------:|
# | United States  |                      1.7 |                      0.9 |
# | United Kingdom |                      2.4 |                      0.5 |
# | Germany        |                      2.4 |                      1.1 |
# | France         |                      2.6 |                      0.9 |
# | Japan          |                      3   |                      1.2 |
# | New Zealand    |                      1.2 |                      0.5 |

# %% [markdown]
# ### Development accounting

# %%
for var in ['rgdpo','cgdpo','hc','emp','avh','cn','ck','pl_gdpo']:
    print(f'{var} = ', pwt_legend[var])
# Out:
# rgdpo =  Output-side real GDP at chained PPPs (in mil. 2017US$)
# cgdpo =  Output-side real GDP at current PPPs (in mil. 2017US$)
# hc =  Human capital index, based on years of schooling and returns to education; see Human capital in PWT9.
# emp =  Number of persons engaged (in millions)
# avh =  Average annual hours worked by persons engaged
# cn =  Capital stock at current PPPs (in mil. 2017US$)
# ck =  Capital services levels at current PPPs (USA=1)
# pl_gdpo =  Price level of CGDPo (PPP/XR), price level of USA GDPo in 2017=1

# %%
nat_resources = pd.read_stata('./natural_resources.dta')

# %%
da=pwt.merge(nat_resources,on=['countrycode','year'],how='left')

# %%
da['rgdpo_nrc'] = da.rgdpo*(1-da.natural_res/100)
da['cgdpo_nrc'] = da.cgdpo*(1-da.natural_res/100)

# %%
alpha = 1/3
da['output per worker']=(da.rgdpo/(da.emp))
da['capital per worker'] = (da.cn/(da.emp))
da['factor of prod'] = da['capital per worker']**alpha*da['hc']**(1-alpha)
da['productivity'] = da['output per worker']/(da['factor of prod'])
da['output per capita'] = da.rgdpo/da['pop']

# %%
print(da[(da.country=='India') & (da.year.isin([1970,2019]))][
    ['year','output per worker','capital per worker','hc']].round(decimals=2).to_latex(index=False))
# Out:
# \begin{tabular}{rrrr}
# \toprule
#  year &  output per worker &  capital per worker &   hc \\
# \midrule
#  1970 &            4075.74 &            10972.45 & 1.18 \\
#  2019 &           18428.99 &            70986.76 & 2.17 \\
# \bottomrule
# \end{tabular}

# %%
# alpha = 1/3
# da['output per worker']=(da.rgdpo_nrc/(da.emp*da.avh))
# da['capital per worker'] = (da.cn/(da.emp*da.avh))
# da['factor of prod'] = da['capital per worker']**alpha*da['hc']**(1-alpha)
# da['productivity'] = da['output per worker']/(da['factor of prod'])

# %%
da = da[['country','countrycode','year','output per worker','capital per worker','hc','factor of prod','productivity']].dropna()

# %%
usa = da[da.countrycode=='USA'].drop(['country','countrycode'],axis=1)
usa.columns = ['year'] + [f'{var}, US' for var in usa.columns[1:]]
da=da.merge(usa,on='year',how='left')

# %%
for var in ['output per worker','capital per worker','hc','factor of prod','productivity']:
    da[f'rel {var}'] = da[var]/da[f'{var}, US']

# %%
da_2018 = da[da.year == 2018].copy()

# %%
da_2018['output per worker, q']=pd.qcut(da_2018['output per worker'],q=5,labels=False)+1

# %%
da_2018['Quintile']=da_2018['output per worker, q'].map(
    {1:'Poorest 20%',2:'Second-poorest 20%',3:'Middle 20%',4:'Second-richest 20%',5:'Richest 20%'})

# %%
da_2018.sort_values('output per worker, q',inplace=True)

# %%
country_list = ['United States','Norway','United Kingdom','Canada',
               'Japan','Republic of Korea','Mexico',
               'Brazil','India','Russian Federation','Myanmar','Germany','Mali']
markdown_ = False
if markdown_:
    print(tabulate(da_2018[da_2018.country.isin(country_list)][['country','rel output per worker','rel capital per worker',
            'rel hc','rel factor of prod','rel productivity']].round(decimals=2),
                   tablefmt="pipe", 
                   showindex=False,headers="keys"))
da_2018[da_2018.country.isin(country_list)][['country','rel output per worker','rel capital per worker',
             'rel hc','rel factor of prod','rel productivity']].round(decimals=2)
# Out:
#                  country  rel output per worker  rel capital per worker  \
# 4985                Mali                   0.06                    0.03
# 3400               India                   0.14                    0.16
# 5109             Myanmar                   0.09                    0.08
# 4925              Mexico                   0.35                    0.46
# 939               Brazil                   0.26                    0.34
# 6513  Russian Federation                   0.45                    0.62
# 4245   Republic of Korea                   0.62                    0.94
# 3998               Japan                   0.56                    0.86
# 7847       United States                   1.00                    1.00
# 1976             Germany                   0.75                    1.07
# 1209              Canada                   0.75                    1.04
# 2785      United Kingdom                   0.71                    1.07
# ...

# %%
0.39/0.74
# Out:
# 0.5270270270270271

# %%
fig,ax=plt.subplots(figsize=(8,6))
sns.barplot(y="Quintile", x="rel output per worker",palette=colors[0], capsize=.3,data=da_2018)
plt.ylabel("")
plt.xlabel("")
plt.title('Output per worker relative to U.S.');
plt.savefig('../files/rel_output.svg',bbox_inches='tight')

# %%
fig,ax=plt.subplots(figsize=(8,6))
sns.barplot(y="Quintile", x="rel factor of prod",palette=colors[0], capsize=.3,data=da_2018)
plt.ylabel("")
plt.xlabel("")
plt.title('Factors of production per worker relative to U.S.');
plt.savefig('../files/rel_factor.svg',bbox_inches='tight')

# %%
fig,ax=plt.subplots(figsize=(8,6))
sns.barplot(y="Quintile", x="rel productivity",palette=colors[0], capsize=.3,data=da_2018)
plt.ylabel("")
plt.xlabel("")
plt.title('Productivity relative to U.S.');
plt.savefig('../files/rel_prod.svg',bbox_inches='tight')

# %%
(da_2018.groupby(['Quintile'])[['rel productivity','rel factor of prod']].mean()*100).round(decimals=0)
# Out:
#                     rel productivity  rel factor of prod
# Quintile
# Middle 20%                      52.0                57.0
# Poorest 20%                     22.0                21.0
# Richest 20%                     91.0               100.0
# Second-poorest 20%              36.0                39.0
# Second-richest 20%              64.0                79.0

# %%
var_y = np.log(da_2018['rel output per worker']).var()
var_a = np.log(da_2018['rel productivity']).var()
var_f = np.log(da_2018['rel factor of prod']).var()
cov_a_f = np.log(da_2018[['rel factor of prod','rel productivity']]).cov()

# %%
((var_a+cov_a_f.iloc[1]['rel factor of prod'])/var_y ).round(decimals=2)
# Out:
# 0.49

# %%
((var_f+cov_a_f.iloc[1]['rel factor of prod'])/var_y ).round(decimals=2)
# Out:
# 0.51

# %% [markdown]
# ### Growth accounting

# %%
def growth_pwt(group,var_list,begin=year_0,end=year_last):
    vals = []
    for var in var_list:
        try:
            g_1 = np.log(group[group.year==end][var].values[0]/
                   group[group.year==begin][var].values[0])/(end-begin)
        except Exception:
            g_1 = np.nan
        vals.append(g_1*100)
    return pd.Series(dict(zip(var_list,vals)))

# %%
da_growth=da.groupby(['country','countrycode']).apply(growth_pwt,['output per worker',
                    'capital per worker','hc','factor of prod','productivity'],1970,2018)

# %%
weights = [alpha,1-alpha,1,1]
for i,var in enumerate(['capital per worker','hc','factor of prod','productivity']):
    da_growth[f'cont {var}'] = da_growth[var]*weights[i]/da_growth['output per worker']

# %%
da_growth.loc[country_list].round(decimals=2)
# Out:
#                                 output per worker  capital per worker    hc  \
# country            countrycode
# United States      USA                       1.49                1.13  0.42
# Norway             NOR                       3.08                2.45  0.57
# United Kingdom     GBR                       1.85                2.47  0.66
# Canada             CAN                       1.13                1.88  0.56
# Japan              JPN                       2.22                3.31  0.51
# Republic of Korea  KOR                       4.96                5.28  1.32
# Mexico             MEX                       0.29                1.37  0.97
# Brazil             BRA                       2.08                3.70  1.44
# India              IND                       3.11                3.81  1.25
# Russian Federation RUS                        NaN                 NaN   NaN
# Myanmar            MMR                       3.68                8.09  0.95
#
# ...

# %%
da_growth['output per worker, q']=pd.qcut(da_growth['output per worker'],q=5,labels=False)+1

# %%
da_growth['Quintile']=da_growth['output per worker, q'].map(
    {1:'Lowest growth 20%',2:'Second-lowest growth 20%',3:'Middle growth 20%'
     ,4:'Second-highest growth 20%',5:'Highest growth 20%'})

# %%
da_growth.sort_values('output per worker, q',inplace=True)

# %%
da_growth.groupby('Quintile')[['productivity']].describe().round(decimals=2)
# Out:
#                           productivity                                      \
#                                  count  mean   std   min   25%   50%   75%
# Quintile
# Highest growth 20%                22.0  1.25  0.66  0.35  0.71  1.00  1.87
# Lowest growth 20%                 22.0 -1.79  1.68 -7.67 -2.05 -1.23 -0.88
# Middle growth 20%                 22.0  0.08  0.64 -1.32 -0.39  0.28  0.58
# Second-highest growth 20%         21.0  0.48  0.38 -0.21  0.26  0.52  0.73
# Second-lowest growth 20%          21.0 -0.17  0.58 -1.28 -0.53 -0.24  0.13
#
#
#                             max
# Quintile
# Highest growth 20%         2.32
# Lowest growth 20%         -0.22
# Middle growth 20%          0.77
# Second-highest growth 20%  1.24
# Second-lowest growth 20%   0.83

# %%
var_y = (da_growth['output per worker']).var()
var_a = (da_growth['productivity']).var()
var_f = (da_growth['factor of prod']).var()
cov_a_f =(da_growth[['factor of prod','productivity']]).cov()

# %%
((var_a+cov_a_f.iloc[1]['factor of prod'])/var_y ).round(decimals=2)
# Out:
# 0.71

# %%
((var_f+cov_a_f.iloc[1]['factor of prod'])/var_y ).round(decimals=2)
# Out:
# 0.29

# %%
fig,ax=plt.subplots(figsize=(8,6))
sns.barplot(y="Quintile", x="output per worker",palette=colors[0], capsize=.3,data=da_growth)
plt.ylabel("")
plt.xlabel("")
plt.title('Growth rate of output per worker, 1970-2018');
plt.savefig('../files/growth_output.svg',bbox_inches='tight')

# %%
fig,ax=plt.subplots(figsize=(8,6))
sns.barplot(y="Quintile", x="capital per worker",palette=colors[0], capsize=.3,data=da_growth)
plt.ylabel("")
plt.xlabel("")
plt.title('Growth rate of capital per worker, 1970-2018');
plt.savefig('../files/growth_cap.svg',bbox_inches='tight')

# %%
fig,ax=plt.subplots(figsize=(8,6))
sns.barplot(y="Quintile", x="factor of prod",palette=colors[0], capsize=.3,data=da_growth)
plt.ylabel("")
plt.xlabel("")
plt.title('Growth rate of factors of production, 1970-2018');
plt.savefig('../files/growth_factor.svg',bbox_inches='tight')

# %%
fig,ax=plt.subplots(figsize=(8,6))
sns.barplot(y="Quintile", x="productivity",palette=colors[0], capsize=.3,data=da_growth)
plt.ylabel("")
plt.xlabel("")
plt.title('Growth rate of productivity, 1970-2018');
plt.savefig('../files/growth_prod.svg',bbox_inches='tight')

# %%
da_growth[['output per worker','productivity','factor of prod']].describe().round(decimals=2)
# Out:
#        output per worker  productivity  factor of prod
# count             108.00        108.00          108.00
# mean                1.62         -0.04            1.66
# std                 1.77          1.35            0.72
# min                -7.79         -7.67           -0.12
# 25%                 0.98         -0.76            1.19
# 50%                 1.70          0.25            1.62
# 75%                 2.46          0.70            2.13
# max                 5.65          2.32            3.72

# %% [markdown]
# ### Development Accounting, alternative
#
# $$ \ln \frac{Y}{L}  = \ln Z+\frac{\alpha}{1-\alpha}\ln \frac{K}{L} + \ln \frac{H}{L}, \text{ where } Z \equiv A^{\frac{1}{1-\alpha}}$$

# %%
for var in ['rgdpo','cgdpo','hc','emp','avh','cn','ck','pl_gdpo']:
    print(f'{var} = ', pwt_legend[var])
# Out:
# rgdpo =  Output-side real GDP at chained PPPs (in mil. 2017US$)
# cgdpo =  Output-side real GDP at current PPPs (in mil. 2017US$)
# hc =  Human capital index, based on years of schooling and returns to education; see Human capital in PWT9.
# emp =  Number of persons engaged (in millions)
# avh =  Average annual hours worked by persons engaged
# cn =  Capital stock at current PPPs (in mil. 2017US$)
# ck =  Capital services levels at current PPPs (USA=1)
# pl_gdpo =  Price level of CGDPo (PPP/XR), price level of USA GDPo in 2017=1

# %%
alpha     = 0.33
year_base = 2017

# %%
nat_resources = pd.read_stata('./natural_resources.dta')

# %%
pwt=pwt.merge(nat_resources,on=['countrycode','year'],how='left')

# %%
pwt['rgdpo_nrc'] = pwt.rgdpo*(1-pwt.natural_res/100)
pwt['cgdpo_nrc'] = pwt.cgdpo*(1-pwt.natural_res/100)

# %%
pwt['output per worker']=(pwt.rgdpo_nrc/(pwt.emp*pwt.avh))
pwt['capital output ratio'] = (pwt.cn/pwt.rgdpo_nrc)**(alpha/(1-alpha))
pwt['human capital'] = (pwt.hc)
pwt['tfp residual'] = pwt['output per worker']/pwt['capital output ratio']/pwt['human capital']

# %%
df = pwt[['country','countrycode','year','output per worker','capital output ratio','human capital','tfp residual']].dropna()

# %%
usa = df[df.countrycode=='USA'].drop(['country','countrycode'],axis=1)
usa.columns = ['year'] + [f'{var}, US' for var in usa.columns[1:]]
df=df.merge(usa,on='year',how='left')

# %%
for var in ['output per worker','capital output ratio','human capital','tfp residual']:
    df[f'rel {var}'] = df[var]/df[f'{var}, US']

# %%
df['overall diff'] = 1/df['rel output per worker']
df['contrib capital'] = 1/df['rel capital output ratio']
df['contrib hc'] = 1/df['rel human capital']
df['contrib tfp'] = 1/df['rel tfp residual']

# %%
df['share due to tfp'] = df['contrib tfp']/(df['contrib capital']*df['contrib hc']+df['contrib tfp'])

# %%
select = (df.year == 2017) & (df.country.isin(['Singapore','France','Germany']))
df[select][['country','share due to tfp']+[f'rel {var}' for 
            var in ['output per worker','capital output ratio','human capital','tfp residual']]].round(decimals=3)
# Out:
#         country  share due to tfp  rel output per worker  \
# 692     Germany             0.579                  0.979
# 965      France             0.573                  0.958
# 2343  Singapore             0.652                  0.761
#
#       rel capital output ratio  rel human capital  rel tfp residual
# 692                      1.182              0.982             0.843
# 965                      1.328              0.853             0.845
# 2343                     1.124              1.063             0.637

# %%
1/0.477/(1/0.931*1/0.76+1/0.477)
# Out:
# 0.5973188356858242

# %%
1/0.931,1/0.76,1/0.477
# Out:
# (1.0741138560687433, 1.3157894736842106, 2.0964360587002098)

# %%
year_ = 1956
pwt = pwt.merge(pwt[pwt.year==year_][['countrycode','rtfpna']].rename(columns={'rtfpna':f'rtfpna, {year_}'})
          ,on='countrycode',how='left')

# %%
pwt[f'rtfpna, {year_}=1'] = pwt.rtfpna/pwt[f'rtfpna, {year_}']

# %%
#country_list = ['USA','GBR']
pwt2 = pwt[pwt.countrycode.isin(country_list)]

# %%
color_list = dict(zip(country_list,colors[:len(country_list)]))
fig,ax = plt.subplots()
sns.lineplot(x='year',y=f'rtfpna, {year_}=1',hue='countrycode',linewidth=2,
             palette=color_list,legend=False,data=pwt2)
for i,country in enumerate(country_list):
    pwt3 = pwt2[pwt2.countrycode==country]
    label = pwt3.country.unique()[0]
    if label == 'United Kingdom':
        loc_ = (2018,pwt3[pwt3.year==2016][f'rtfpna, {year_}=1']-.05)
    else:
        loc_ = (2018,pwt3[pwt3.year==2016][f'rtfpna, {year_}=1'])
    ax.annotate(label,loc_,color=colors[i],fontsize=16)
ax.set_xlabel('Year')
ax.set_ylabel(f'TFP ({year_}=1)');
ax.set_xlim(xmax=2022,xmin=1948)
#ax.legend(loc='upper left',frameon=False)
ax.spines["left"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
#plt.text(loc_all[0],loc_all[1],source)
plt.savefig('./tfp-over-time.svg',bbox_inches='tight')

# %%
color_list = dict(zip(country_list,colors[:len(country_list)]))
fig,ax = plt.subplots()
sns.lineplot(x='year',y='ctfp',hue='countrycode',linewidth=2,
             palette=color_list,legend=False,data=pwt2)
for i,country in enumerate(country_list):
    pwt3 = pwt2[pwt2.countrycode==country]
    label = pwt3.country.unique()[0]
    if label == 'Japan':
        loc_ = (2018,pwt3[pwt3.year==2016]['ctfp']-.03)    
    else:
        loc_ = (2018,pwt3[pwt3.year==2016]['ctfp'])
    ax.annotate(label,loc_,color=colors[i],fontsize=16)
ax.set_xlabel('Year')
ax.set_ylabel('TFP (USA=1)');
ax.set_xlim(xmax=2022,xmin=1948)
#ax.legend(loc='upper left',frameon=False)
ax.spines["left"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
#plt.text(loc_all[0],loc_all[1],source)
plt.savefig('./tfp-over-time-rel-usa.svg',bbox_inches='tight')

# %%
df=df.merge(pwt[['countrycode','year','emp']],on=['countrycode','year'],how='left')

# %%
df.sort_values(['countrycode','year'],inplace=True)

# %%
df_legend['rgdpnapc']
# Out:
# 'Real GDP per capita in 2011US$, 2011 benchmark (suitable for cross-country growth comparisons)'

# %%
growth_rates = (df[df.year.isin([1960,2016])].groupby(['countrycode','country']).apply(lambda x:
                100*(np.log(x.iloc[1]['rgdpnapc'])-np.log(x.iloc[0]['rgdpnapc']))/56).reset_index().
                rename(columns={0:'Avg. Growth (1960-2016)'}))

# %%
growth_rates['Years to double'] = 72/growth_rates['Avg. Growth (1960-2016)']

# %%
growth_rates[growth_rates.countrycode=='ESP']
# Out:
#    countrycode country  Avg. Growth (1960-2016)  Years to double
# 47         ESP   Spain                 2.892477        24.892164

# %%
df_legend['pop']
# Out:
# 'Population, mid-year (thousands)'

# %%
pwt_legend['emp']
# Out:
# 'Number of persons engaged (in millions)'

# %%
df['pop'] = df['pop']/1000

# %%
df['E/pop'] = df['emp']/df['pop']*100

# %%
df_legend['cgdppc']
# Out:
# 'Real GDP per capita in 2011US$, multiple benchmarks (suitable for cross-country income comparisons)'

# %%
df['GDP per worker'] = df['cgdppc']*df['pop']/df['emp']

# %%
df=df.merge(growth_rates,on=['countrycode','country'])

# %%
rich_countries = ['USA','JPN','FRA','GBR','ESP']

# %%
rich_table = df[(df.countrycode.isin(rich_countries))&(df.year==2016)]

# %%
rich_table
# Out:
#       countrycode         country  year   cgdppc  rgdpnapc      pop  \
# 5258          ESP           Spain  2016  31556.0   30110.0   47.024
# 6312          FRA          France  2016  38758.0   37124.0   66.957
# 6708          GBR  United Kingdom  2016  39162.0   37334.0   65.888
# 9486          JPN           Japan  2016  36452.0   37465.0  126.310
# 18959         USA   United States  2016  53015.0   53015.0  324.656
#
#               i_cig i_bm         emp      E/pop  GDP per worker  \
# 5258   Extrapolated  NaN   18.699034  39.764873    79356.471829
# 6312   Extrapolated  NaN   27.622475  41.254051    93949.562339
# 6708   Extrapolated  NaN   31.683855  48.087444    81439.138368
# 9486   Extrapolated  NaN   67.613182  53.529556    68096.959486
# 18959  Extrapolated  NaN  152.632553  47.013625   112765.183379
#
#        Avg. Growth (1960-2016)  Years to double
# 5258                  2.892477        24.892164
# 6312                  1.991589        36.152040
# ...

# %%
rich_table = (rich_table[['country','year','cgdppc','GDP per worker','E/pop','Avg. Growth (1960-2016)','Years to double']]
             .rename(columns={'cgdppc':'GDP per capita',
                             'country':'Country',
                             'year':'Year'}).set_index(['Country','Year']))

# %%
rich_table.round(decimals=1)
# Out:
#                      GDP per capita  GDP per worker  E/pop  \
# Country        Year
# Spain          2016         31556.0         79356.5   39.8
# France         2016         38758.0         93949.6   41.3
# United Kingdom 2016         39162.0         81439.1   48.1
# Japan          2016         36452.0         68097.0   53.5
# United States  2016         53015.0        112765.2   47.0
#
#                      Avg. Growth (1960-2016)  Years to double
# Country        Year
# Spain          2016                      2.9             24.9
# France         2016                      2.0             36.2
# United Kingdom 2016                      1.8             39.7
# Japan          2016                      3.2             22.6
# United States  2016                      1.9             37.4

# %%
poor_countries = ['CHN','IND','NGA','UGA']

# %%
poor_table = df[(df.countrycode.isin(poor_countries))&(df.year==2016)]

# %%
poor_table = (poor_table[['country','year','cgdppc','GDP per worker','E/pop','Avg. Growth (1960-2016)','Years to double']]
             .rename(columns={'cgdppc':'GDP per capita',
                             'country':'Country',
                             'year':'Year'}).set_index(['Country','Year']))

# %%
poor_table.round(decimals=1)
# Out:
#               GDP per capita  GDP per worker  E/pop  Avg. Growth (1960-2016)  \
# Country Year
# China   2016         12320.0         21340.1   57.7                      4.8
# India   2016          5961.0         14248.7   41.8                      3.2
# Nigeria 2016          5323.0         15641.8   34.0                      1.6
# Uganda  2016          1909.0          5036.0   37.9                      1.0
#
#               Years to double
# Country Year
# China   2016             14.9
# India   2016             22.3
# Nigeria 2016             43.8
# Uganda  2016             69.3

# %%
miracles = ['HKG','SGP','TWN','KOR']

# %%
miracles_table = df[(df.countrycode.isin(miracles))&(df.year==2016)]

# %%
miracles_table = (miracles_table[['country','year','cgdppc','GDP per worker','E/pop','Avg. Growth (1960-2016)','Years to double']]
             .rename(columns={'cgdppc':'GDP per capita',
                             'country':'Country',
                             'year':'Year'}).set_index(['Country','Year']))

# %%
miracles_table.round(decimals=1)
# Out:
#                                 GDP per capita  GDP per worker  E/pop  \
# Country                   Year
# China, Hong Kong SAR      2016         47043.0         89121.0   52.8
# Republic of Korea         2016         36151.0         71246.1   50.7
# Singapore                 2016         67180.0        108866.5   61.7
# Taiwan, Province of China 2016         42304.0         84298.5   50.2
#
#                                 Avg. Growth (1960-2016)  Years to double
# Country                   Year
# China, Hong Kong SAR      2016                      4.3             16.7
# Republic of Korea         2016                      5.5             13.2
# Singapore                 2016                      4.8             14.9
# Taiwan, Province of China 2016                      5.4             13.2

# %%
disasters = ['VEN','HTI','MDG','ZWE']

# %%
disasters_table = df[(df.countrycode.isin(disasters))&(df.year==2016)]

# %%
disasters_table = (disasters_table[['country','year','cgdppc','GDP per worker','E/pop','Avg. Growth (1960-2016)','Years to double']]
             .rename(columns={'cgdppc':'GDP per capita',
                             'country':'Country',
                             'year':'Year'}).set_index(['Country','Year']))

# %%
disasters_table.round(decimals=1)
# Out:
#                                          GDP per capita  GDP per worker  \
# Country                            Year
# Haiti                              2016          1636.0          4066.2
# Madagascar                         2016          1307.0          2528.6
# Venezuela (Bolivarian Republic of) 2016         13159.0         28878.4
# Zimbabwe                           2016          1729.0          2845.4
#
#                                          E/pop  Avg. Growth (1960-2016)  \
# Country                            Year
# Haiti                              2016   40.2                     -0.7
# Madagascar                         2016   51.7                     -0.9
# Venezuela (Bolivarian Republic of) 2016   45.6                      0.2
# Zimbabwe                           2016   60.8                     -0.0
#
#                                          Years to double
# Country                            Year
# Haiti                              2016           -107.8
# ...

# %%
from tabulate import tabulate

# %%
print(tabulate(disasters_table.round(decimals=1).reset_index(), tablefmt="pipe", 
               showindex=False,headers="keys"))
# Out:
# | Country                            |   Year |   GDP per capita |   GDP per worker |   E/pop |   Avg. Growth (1960-2016) |   Years to double |
# |:-----------------------------------|-------:|-----------------:|-----------------:|--------:|--------------------------:|------------------:|
# | Haiti                              |   2016 |             1636 |           4066.2 |    40.2 |                      -0.7 |            -107.8 |
# | Madagascar                         |   2016 |             1307 |           2528.6 |    51.7 |                      -0.9 |             -80.8 |
# | Venezuela (Bolivarian Republic of) |   2016 |            13159 |          28878.4 |    45.6 |                       0.2 |             375.1 |
# | Zimbabwe                           |   2016 |             1729 |           2845.4 |    60.8 |                      -0   |           -6205.2 |

# %%
df[df.year==2016].head()
# Out:
#     countrycode               country  year   cgdppc  rgdpnapc     pop  \
# 69          AFG           Afghanistan  2016   1929.0    1929.0  33.332
# 136         AGO                Angola  2016   8397.0    8453.0  17.644
# 245         ALB               Albania  2016  11285.0   10342.0   3.044
# 312         ARE  United Arab Emirates  2016  70284.0   75876.0   9.343
# 459         ARG             Argentina  2016  18695.0   18875.0  43.887
#
#             i_cig i_bm        emp      E/pop  GDP per worker  \
# 69   Extrapolated  NaN        NaN        NaN             NaN
# 136  Extrapolated  NaN  14.960469  84.790689     9903.209957
# 245  Extrapolated  NaN   1.002480  32.932992    34266.549757
# 312  Extrapolated  NaN   3.876493  41.490886   169396.239100
# 459  Extrapolated  NaN  19.683954  44.851446    41682.044931
#
#      Avg. Growth (1960-2016)  Years to double
# 69                 -0.629312      -114.410575
# 136                      NaN              NaN
# ...

# %%
df_legend['cgdppc']
# Out:
# 'Real GDP per capita in 2011US$, multiple benchmarks (suitable for cross-country income comparisons)'

# %%
desc_ = df[df.year==2016].cgdppc.describe().reset_index()

# %%
desc_
# Out:
#   Statistic  GDP per capita
# 0     count      166.000000
# 1      mean    18591.698795
# 2       std    19393.210172
# 3       min      619.000000
# 4       25%     3892.250000
# 5       50%    12134.500000
# 6       75%    26450.500000
# 7       max   139783.000000

# %%
desc_.rename(columns={'index':'Statistic','cgdppc':'GDP per capita'},inplace=True)

# %%
print(tabulate(desc_, tablefmt="pipe", 
               showindex=False,headers="keys"))
# Out:
# | Statistic   |   GDP per capita |
# |:------------|-----------------:|
# | count       |           166    |
# | mean        |         18591.7  |
# | std         |         19393.2  |
# | min         |           619    |
# | 25%         |          3892.25 |
# | 50%         |         12134.5  |
# | 75%         |         26450.5  |
# | max         |        139783    |

# %%
619/139783
# Out:
# 0.004428292424686836

# %%
fig,ax=plt.subplots(figsize=(8,6))
sns.distplot(df[df.year==2016]['cgdppc'].dropna(),
             ax=ax,color=colors[2],kde=False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.set_xlabel('GDP per capita')
ax.set_ylabel('Count')
ax.set_xlim(xmin=-5000)
ax.set_ylim(ymin=-3)
ax.text(-2,-18,'Source: Maddison Project Database (MPD) 2018')
plt.savefig('./income-histogram.svg',bbox_inches='tight')

# %%
desc_2 = df[df.year==2016]['Avg. Growth (1960-2016)'].describe().reset_index()

# %%
desc_2.rename(columns={'index':'Statistic','cgdppc':'GDP per capita'},inplace=True)

# %%
desc_2[]
# Out:
#   Statistic  Avg. Growth (1960-2016)
# 0     count               144.000000
# 1      mean                 1.902013
# 2       std                 1.341066
# 3       min                -1.733580
# 4       25%                 1.118516
# 5       50%                 1.894071
# 6       75%                 2.656533
# 7       max                 5.885369

# %%
print(tabulate(desc_2, tablefmt="pipe", 
               showindex=False,headers="keys"))
# Out:
# | Statistic   |   Avg. Growth (1960-2016) |
# |:------------|--------------------------:|
# | count       |                 144       |
# | mean        |                   1.90201 |
# | std         |                   1.34107 |
# | min         |                  -1.73358 |
# | 25%         |                   1.11852 |
# | 50%         |                   1.89407 |
# | 75%         |                   2.65653 |
# | max         |                   5.88537 |

# %%
fig,ax=plt.subplots(figsize=(8,6))
sns.distplot(df[df.year==2016]['Avg. Growth (1960-2016)'].dropna(),
             ax=ax,color=colors[2],kde=False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.set_xlabel('Growth Rate, %')
ax.set_ylabel('Count')
ax.set_ylim(ymin=-1,ymax=37)
ax.text(-2,-9,'Source: Maddison Project Database (MPD) 2018')
plt.savefig('./growth-histogram.svg',bbox_inches='tight')

# %%
country_list = ['USA','IRN','MDA','ETH']

# %%
df[df.countrycode.isin(['USA','GBR']) & (df.year.isin([1870,2016]))]
# Out:
#       countrycode         country  year   cgdppc  rgdpnapc      pop  \
# 6562          GBR  United Kingdom  1870   3846.0    5716.0   31.400
# 6708          GBR  United Kingdom  2016  39162.0   37334.0   65.888
# 18813         USA   United States  1870   3736.0    3736.0   40.241
# 18959         USA   United States  2016  53015.0   53015.0  324.656
#
#               i_cig i_bm         emp      E/pop  GDP per worker  \
# 6562   Extrapolated  NaN         NaN        NaN             NaN
# 6708   Extrapolated  NaN   31.683855  48.087444    81439.138368
# 18813  Extrapolated  NaN         NaN        NaN             NaN
# 18959  Extrapolated  NaN  152.632553  47.013625   112765.183379
#
#        Avg. Growth (1960-2016)  Years to double
# 6562                  1.814868        39.672300
# 6708                  1.814868        39.672300
# 18813                 1.923189        37.437809
# 18959                 1.923189        37.437809

# %%
(np.log(53015.0)-np.log(3736.0))/(2016-1870)
# Out:
# 0.018168214876788803

# %%
(np.log(37334.0)-np.log(5716.0))/(2016-1870)
# Out:
# 0.012853665613306742

# %%
np.log(3846.0)-np.log(3736.0)
# Out:
# 0.029018126799991606

# %%
np.log(39162.0)-np.log(53015.0)
# Out:
# -0.3028680034966271

# %%
df[df.countrycode.isin(country_list) & (df.year == 2016)]
# Out:
#       countrycode                     country  year   cgdppc  rgdpnapc  \
# 5398          ETH                    Ethiopia  2016   1659.0    1635.0
# 8643          IRN  Iran (Islamic Republic of)  2016  15529.0   16783.0
# 10842         MDA         Republic of Moldova  2016   5851.0    6068.0
# 18959         USA               United States  2016  53015.0   53015.0
#
#            pop         i_cig i_bm         emp      E/pop  GDP per worker  \
# 5398   110.945  Extrapolated  NaN   46.504700  41.916895     3957.831276
# 8643    80.755  Extrapolated  NaN   22.591078  27.974835    55510.604932
# 10842    3.527  Extrapolated  NaN    1.403688  39.798347    14701.615446
# 18959  324.656  Extrapolated  NaN  152.632553  47.013625   112765.183379
#
#        Avg. Growth (1960-2016)  Years to double
# 5398                  1.829238        39.360652
# 8643                  1.835906        39.217703
# 10842                      NaN              NaN
# 18959                 1.923189        37.437809

# %%
5851.0/1659.0
# Out:
# 3.526823387582881

# %%
country_list = ['USA','GBR','JPN','KOR','ARG','HTI']

# %%
groups = [0,2,4,5,6]

# %%
color_codes = dict(zip(country_list,colors))

# %%
df.head()
# Out:
#   countrycode      country  year  cgdppc  rgdpnapc    pop         i_cig i_bm  \
# 0         AFG  Afghanistan  1820     NaN       NaN  3.280           NaN  NaN
# 1         AFG  Afghanistan  1870     NaN       NaN  4.207           NaN  NaN
# 2         AFG  Afghanistan  1913     NaN       NaN  5.730           NaN  NaN
# 3         AFG  Afghanistan  1950  2392.0    2392.0  8.150  Extrapolated  NaN
# 4         AFG  Afghanistan  1951  2422.0    2422.0  8.284  Extrapolated  NaN
#
#    emp  E/pop  GDP per worker  Avg. Growth (1960-2016)  Years to double
# 0  NaN    NaN             NaN                -0.629312      -114.410575
# 1  NaN    NaN             NaN                -0.629312      -114.410575
# 2  NaN    NaN             NaN                -0.629312      -114.410575
# 3  NaN    NaN             NaN                -0.629312      -114.410575
# 4  NaN    NaN             NaN                -0.629312      -114.410575

# %%
df_legend['cgdppc']
# Out:
# 'Real GDP per capita in 2011US$, multiple benchmarks (suitable for cross-country income comparisons)'

# %%
alphas = dict(zip(country_list,np.ones(len(country_list))))

# %%
annotate={'USA':(1935,25000),
         'GBR':(1910,4500),
         'JPN':(1900,2200),
         'KOR':(1982,5000),
         'ARG':(2010,15000),
         'HTI':(2010,1800)}
ticks = np.array([.5,1,5,30,60],dtype=int)
for group in groups[1:]:
    fig,ax = plt.subplots(figsize=(8,6))
    file_name = './gdp-per-capita'
    for country in country_list[:group]:
        data = df[(df.countrycode==country) & (df.year>=1880)]
        country_name = data.country.unique()[0]
        ax.plot(data.year,data.cgdppc,color_codes[country],linewidth=2,alpha=alphas[country])
        ax.set_yscale('log')
        ax.set_yticks(ticks*1000)
        ax.set_ylim(ymin=500,ymax=65000)
        ax.set_xlim(xmax=2039)
        ax.set_yticklabels((ticks))
        ax.annotate(country_name,annotate[country],color=color_codes[country],alpha=alphas[country])
        ax.spines['left'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.spines['top'].set_visible(False)
        ax.spines['bottom'].set_visible(False)
        ax.set_xlabel('Year')
        ax.set_ylabel('GDP per capita in thousand 2011US$')
        file_name += f'_{country}'
        alphas[country]=.3
    plt.savefig(file_name+'.svg',bbox_inches='tight')

# %%
df_income = df[df.year.isin([1960,2016])][['country','countrycode','year','cgdppc']]

# %%
df_income=df_income.pivot_table(index=['country','countrycode'],values='cgdppc',columns=['year'])

# %%
df_income.dropna(inplace=True)

# %%
USA_income = df_income.xs('USA',level=1)

# %%
df_income[1960]=df_income[1960]/USA_income[1960].values[0]
df_income[2016]=df_income[2016]/USA_income[2016].values[0]

# %%
df_income.reset_index(inplace=True)

# %%
df_income=df_income.merge(df[df.year==2016][['countrycode','country','pop']],on=['countrycode','country'],how='left')

# %%
df_income.dropna(inplace=True)

# %%
fig,ax = plt.subplots(figsize=(8,8))
ax.scatter(df_income[1960],df_income[2016],color='k',sizes=df_income['pop'],alpha=.7)
ax.plot(np.linspace(0,1.2),np.linspace(0,1.2),color='r',linewidth=2)
ax.set_xlim(xmin=-0.1,xmax=1.31)
ax.set_ylim(ymin=-0.1,ymax=1.31)
ax.set_xlabel('GDP per capita relative to the US in 1960')
ax.set_ylabel('GDP per capita relative to the US in 2016')
ax.annotate('$45^\circ$',(1.2,1.2),color='r')
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
usa_ = df_income[df_income.countrycode=='USA'][[1960,2016]].values[0]
gbr_ = df_income[df_income.countrycode=='GBR'][[1960,2016]].values[0]
chn_ = df_income[df_income.countrycode=='CHN'][[1960,2016]].values[0]
ind_ = df_income[df_income.countrycode=='IND'][[1960,2016]].values[0]
deu_ = df_income[df_income.countrycode=='DEU'][[1960,2016]].values[0]

ax.annotate(
    "USA", xy=(usa_[0],usa_[1]), xycoords="data",
    xytext=(25, -25), textcoords="offset points",
    arrowprops=dict(arrowstyle="->", color='k',connectionstyle="arc3,rad=0.6"))
ax.annotate(
    "GBR", xy=(gbr_[0],gbr_[1]), xycoords="data",
    xytext=(25, -25), textcoords="offset points",
    arrowprops=dict(arrowstyle="->", color='k',connectionstyle="arc3,rad=0.6"))
ax.annotate(
    "DEU", xy=(deu_[0],deu_[1]), xycoords="data",
    xytext=(-35, 35), textcoords="offset points",
    arrowprops=dict(arrowstyle="->", color='k',connectionstyle="arc3,rad=0.6"))
ax.annotate(
    "CHN", xy=(chn_[0],chn_[1]), xycoords="data",
    xytext=(-35, 35), textcoords="offset points",
    arrowprops=dict(arrowstyle="->", color='k',connectionstyle="arc3,rad=0.6"))
ax.annotate(
    "IND", xy=(ind_[0],ind_[1]), xycoords="data",
    xytext=(35, -35), textcoords="offset points",
    arrowprops=dict(arrowstyle="->", color='k',connectionstyle="arc3,rad=0.6"))
plt.savefig('./scatter-gdp-size.svg',bbox_inches='tight')

# %%
import plotly_express as px

# %%
import plotly as py
py.offline.init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
data = px.scatter(df_income, x=1960, y=2016,size='pop',
           labels={1960:'GDP per capita relative to the US, 1960',
                  2016:'GDP per capita relative to the US, 2016',
                  'pop':'Population'},hover_name='country',
          width=500,height=500,range_x=(0,1.3),range_y=(0,1.3),
          template='plotly_white')
py.offline.plot(data, filename='myplot.html')
# Out:
# 'file://C:\\Users\\ig212\\Dropbox\\Kent-Teaching\\EconomicGrowth\\economicgrowth\\lecture1\\visuals\\myplot.html'

# %%
df_income.head()
# Out:
#        country countrycode      1960      2016     pop
# 0  Afghanistan         AFG  0.151955  0.036386  33.332
# 1      Albania         ALB  0.118618  0.212864   3.044
# 2    Argentina         ARG  0.494407  0.352636  43.887
# 3    Australia         AUS  0.841511  0.844723  23.978
# 4      Austria         AUT  0.471149  0.849005   8.780

# %%
# Out:
# <div id="9869a529-1eb4-41cc-8c44-f231e0c9fc5d" style="height: 600px; width: 600px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("9869a529-1eb4-41cc-8c44-f231e0c9fc5d")) {
# ...

# %%
df_income[df_income.countrycode=='HTI']#[[1960,2016]].values[0]
# Out:
#    country countrycode      1960      2016     pop
# 55   Haiti         HTI  0.148964  0.030859  10.486

# %%
df_income[df_income.countrycode=='ARG']
# Out:
#      country countrycode      1960      2016     pop
# 2  Argentina         ARG  0.494407  0.352636  43.887

# %%
import statsmodels.api as sm

# %%
GBR = df[df.countrycode=='GBR'].set_index('year').cgdppc.dropna()

# %%
cycle, trend = sm.tsa.filters.hpfilter(GBR.loc[1900:],1600)

# %%
fig,ax = plt.subplots(figsize=(8,6))
ax.plot(GBR.loc[1900:],'r',linewidth=2,label='GDP per capita')
#ax.plot(trend,'k',linewidth=2, label='Trend')
#ax.legend(loc='upper left',frameon=False)
ax.annotate('GDP per capita',(2015,GBR.loc[2010]),color='r',fontsize=16)
#ax.annotate('Trend',(1970,GBR.loc[1990]),color='k',fontsize=16)
ax.set_ylim(ymin = 4000,ymax=42000)
ax.set_ylabel('UK real GDP per capita in 2011US$')
ax.spines["left"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.set_xlabel('Year')
plt.text(1875,-8000,'Source: Maddison Project Database (MPD) 2018',fontsize=16)
plt.savefig('UK-gdp.svg',bbox_inches='tight')
